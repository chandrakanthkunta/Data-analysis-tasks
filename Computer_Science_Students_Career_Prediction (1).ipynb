# %% [markdown]
# link  https://www.kaggle.com/datasets/devildyno/computer-science-students-career-prediction

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv(r"/content/cs_students.csv")

# %%
data
# Out:
#      Student ID            Name  Gender  Age  GPA             Major  \
# 0             1      John Smith    Male   21  3.5  Computer Science
# 1             2   Alice Johnson  Female   20  3.2  Computer Science
# 2             3    Robert Davis    Male   22  3.8  Computer Science
# 3             4    Emily Wilson  Female   21  3.7  Computer Science
# 4             5   Michael Brown    Male   23  3.4  Computer Science
# ..          ...             ...     ...  ...  ...               ...
# 175         176    Elijah Davis    Male   22  3.7  Computer Science
# 176         177    Emma Johnson  Female   20  3.6  Computer Science
# 177         178     Liam Wilson    Male   21  3.4  Computer Science
# 178         179  Sophia Johnson  Female   22  3.5  Computer Science
# 179         180   Michael Brown    Male   23  3.7  Computer Science
#
#            Interested Domain                     Projects  \
# 0    Artificial Intelligence          Chatbot Development
# 1               Data Science               Data Analytics
# 2       Software Development           E-commerce Website
# 3            Web Development           Full-Stack Web App
# 4              Cybersecurity             Network Security
# ..                       ...                          ...
# 175          Web Development           Full-Stack Web App
# 176            Cybersecurity            Security Auditing
# 177         Machine Learning  Natural Language Processing
# 178      Database Management  SQL Database Administration
# 179          Cloud Computing  Cloud Solution Architecture
#
#                     Future Career   Python      SQL     Java
# 0     Machine Learning Researcher   Strong   Strong     Weak
# 1                  Data Scientist  Average   Strong     Weak
# 2               Software Engineer   Strong   Strong  Average
# 3                   Web Developer     Weak   Strong   Strong
# 4    Information Security Analyst  Average     Weak   Strong
# ..                            ...      ...      ...      ...
# 175                 Web Developer     Weak   Strong   Strong
# 176  Information Security Analyst   Strong  Average     Weak
# 177     Machine Learning Engineer   Strong  Average     Weak
# 178        Database Administrator     Weak   Strong  Average
# 179     Cloud Solutions Architect   Strong   Strong     Weak
#
# [180 rows x 12 columns]

# %% [markdown]
# 1. What is the average GPA of students who are interested in Data Science?
# 2. What is the percentage distribution of students by gender?
# 3. How many students have "Strong" Python skills and are interested in Software Development?
# 4. What is the distribution of students' future careers across different majors?
# 5. What is the average age of students with "Strong" SQL skills?
# 6. Who are the students with a GPA above 3.8 and "Strong" Java skills?
# 7. How many students are interested in Cybersecurity and have worked on Network Security projects?
# 8. What is the correlation between age and GPA among students?
# 9. How many students have "Weak" skills in both Python and Java?
# 10. What are the top 3 most common projects worked on by students?
# 11. What is the average GPA of students interested in Artificial Intelligence?
# 12. What is the percentage of students aiming to become Software Engineers?
# 13. What is the distribution of Python skills across different future careers?
# 14. How many students have "Strong" skills in all three programming languages (Python, SQL, Java)?
# 15. What is the most popular interested domain for students with a GPA below 3.0?
# 16. Who are the students with "Weak" SQL skills and want to pursue a career in Data Science?
# 17. What is the gender distribution of students with a GPA above 3.5?
# 18. How many students aged 21 and above are interested in Web Development?
# 19. Which future career is most common among female students?
# 20. What is the average GPA of students aiming to work in Machine Learning?

# %% [markdown]
# 1.What is the average GPA of students who are interested in Data Science?

# %%
data[data['Interested Domain']=='Data Science']
# Out:
#      Student ID                Name  Gender  Age  GPA             Major  \
# 1             2       Alice Johnson  Female   20  3.2  Computer Science
# 45           46   Michelle Williams  Female   20  3.3  Computer Science
# 54           55               Venom    Male   20  3.3  Computer Science
# 63           64             Shocker    Male   20  3.3  Computer Science
# 72           73               MODOK    Male   20  3.3  Computer Science
# 84           85  Agent Lance Hunter    Male   33  3.6  Computer Science
# 90           91           Emily Lee  Female   20  3.7  Computer Science
# 116         117     Michael Johnson    Male   22  3.4  Computer Science
# 133         134        Oliver Davis    Male   23  3.7  Computer Science
# 142         143        Olivia Brown  Female   22  3.5  Computer Science
# 146         147       Joseph Miller    Male   21  3.6  Computer Science
# 162         163        Olivia Brown  Female   22  3.5  Computer Science
# 166         167       Joseph Miller    Male   21  3.6  Computer Science
#
#     Interested Domain              Projects   Future Career   Python      SQL  \
# 1        Data Science        Data Analytics  Data Scientist  Average   Strong
# 45       Data Science      Machine Learning  Data Scientist  Average   Strong
# 54       Data Science      Machine Learning  Data Scientist  Average   Strong
# 63       Data Science      Machine Learning  Data Scientist  Average   Strong
# 72       Data Science      Machine Learning  Data Scientist  Average   Strong
# 84       Data Science      Machine Learning  Data Scientist  Average   Strong
# 90       Data Science  Statistical Analysis    Data Analyst   Strong  Average
# 116      Data Science    Big Data Analytics    Data Analyst  Average   Strong
# 133      Data Science      Machine Learning  Data Scientist  Average   Strong
# 142      Data Science           Data Mining    Data Analyst  Average     Weak
# 146      Data Science      Machine Learning  Data Scientist   Strong  Average
# 162      Data Science           Data Mining    Data Analyst  Average     Weak
# 166      Data Science    Big Data Analytics    Data Analyst  Average   Strong
#
#        Java
# 1      Weak
# 45     Weak
# 54     Weak
# 63     Weak
# 72     Weak
# 84     Weak
# 90     Weak
# 116    Weak
# 133    Weak
# 142  Strong
# 146    Weak
# 162  Strong
# 166    Weak

# %% [markdown]
# 2.What is the percentage distribution of students by gender?

# %%
data['Gender'].value_counts(normalize=True)*100
# Out:
# Gender
# Male      56.666667
# Female    43.333333
# Name: proportion, dtype: float64

# %% [markdown]
# 3.How many students have "Strong" Python skills and are interested in Software Development?

# %%
data[(data['Interested Domain']=='Software Development') & (data['Python']=='Strong')]
# Out:
#      Student ID            Name  Gender  Age  GPA             Major  \
# 2             3    Robert Davis    Male   22  3.8  Computer Science
# 117         118    Olivia Davis  Female   21  3.9  Computer Science
# 134         135  Isabella Brown  Female   20  3.6  Computer Science
# 147         148     Emma Wilson  Female   20  3.8  Computer Science
# 167         168     Emma Wilson  Female   20  3.8  Computer Science
#
#         Interested Domain                     Projects      Future Career  \
# 2    Software Development           E-commerce Website  Software Engineer
# 117  Software Development       Mobile App Development  Software Engineer
# 134  Software Development  Web Application Development  Software Engineer
# 147  Software Development       Mobile App Development  Software Engineer
# 167  Software Development       Mobile App Development  Software Engineer
#
#      Python     SQL     Java
# 2    Strong  Strong  Average
# 117  Strong  Strong  Average
# 134  Strong    Weak   Strong
# 147  Strong  Strong  Average
# 167  Strong  Strong  Average

# %% [markdown]
# 4.What is the distribution of students' future careers across different majors?

# %%
data.groupby('Major')['Future Career'].value_counts()
# Out:
# Major             Future Career
# Computer Science  Web Developer                   19
#                   Mobile App Developer            17
#                   Information Security Analyst    17
#                   Database Administrator          16
#                   Cloud Solutions Architect       16
#                   Software Engineer               14
#                   Machine Learning Engineer       13
#                   NLP Research Scientist          11
#                   Graphics Programmer              9
#                   Data Scientist                   8
#                   AI Researcher                    6
#                   Data Analyst                     6
#                   Game Developer                   4
#                   UX Designer                      2
#                   Bioinformatician                 2
#                   Healthcare IT Specialist         2
#                   Quantum Computing Researcher     2
#                   Computer Vision Engineer         1
#                   VR Developer                     1
#                   Blockchain Engineer              1
#                   Security Analyst                 1
#                   SEO Specialist                   1
#                   Robotics Engineer                1
#                   DevOps Engineer                  1
#                   NLP Engineer                     1
#                   Digital Forensics Specialist     1
#                   Data Privacy Specialist          1
#                   IoT Developer                    1
#                   Geospatial Analyst               1
#                   Ethical Hacker                   1
#                   Embedded Software Engineer       1
#                   Distributed Systems Engineer     1
#                   Machine Learning Researcher      1
# Name: count, dtype: int64

# %% [markdown]
# 5.What is the average age of students with "Strong" SQL skills?

# %%
data[data['SQL']=='Strong']['Age'].mean()
# Out:
# 22.253164556962027

# %% [markdown]
# 6.Who are the students with a GPA above 3.8 and "Strong" Java skills?

# %%
data[(data['GPA']>3.8) & (data['Java']=='Strong')]
# Out:
#      Student ID        Name  Gender  Age  GPA             Major  \
# 81           82  Agent Fitz    Male   35  3.9  Computer Science
# 109         110   Laura Lee  Female   21  3.9  Computer Science
#
#         Interested Domain                       Projects  \
# 81   Software Development          Social Media Platform
# 109   Distributed Systems  Distributed Systems Architect
#
#                     Future Career   Python      SQL    Java
# 81              Software Engineer  Average     Weak  Strong
# 109  Distributed Systems Engineer     Weak  Average  Strong

# %% [markdown]
# 7.How many students are interested in Cybersecurity and have worked on Network Security projects?

# %%
data[(data['Interested Domain']=='Cybersecurity')&(data['Projects']=='Network Security')]
# Out:
#      Student ID               Name  Gender  Age  GPA             Major  \
# 4             5      Michael Brown    Male   23  3.4  Computer Science
# 15           16         John Brown    Male   20  3.6  Computer Science
# 26           27         John Brown    Male   20  3.6  Computer Science
# 37           38         John Brown    Male   20  3.6  Computer Science
# 46           47     Flash Thompson    Male   22  3.7  Computer Science
# 55           56            Carnage    Male   22  3.7  Computer Science
# 64           65  Kraven the Hunter    Male   22  3.7  Computer Science
# 73           74                AIM    Male   22  3.7  Computer Science
# 75           76                AIM  Female   22  3.7  Computer Science
# 77           78         Agent Hill  Female   33  3.8  Computer Science
# 119         120       Emily Wilson  Female   22  3.5  Computer Science
# 129         130      Sophia Wilson  Female   21  3.7  Computer Science
# 149         150     Sophia Johnson  Female   22  3.5  Computer Science
# 169         170     Sophia Johnson  Female   22  3.5  Computer Science
#
#     Interested Domain          Projects                 Future Career  \
# 4       Cybersecurity  Network Security  Information Security Analyst
# 15      Cybersecurity  Network Security  Information Security Analyst
# 26      Cybersecurity  Network Security  Information Security Analyst
# 37      Cybersecurity  Network Security  Information Security Analyst
# 46      Cybersecurity  Network Security  Information Security Analyst
# 55      Cybersecurity  Network Security  Information Security Analyst
# 64      Cybersecurity  Network Security  Information Security Analyst
# 73      Cybersecurity  Network Security  Information Security Analyst
# 75      Cybersecurity  Network Security  Information Security Analyst
# 77      Cybersecurity  Network Security  Information Security Analyst
# 119     Cybersecurity  Network Security  Information Security Analyst
# 129     Cybersecurity  Network Security  Information Security Analyst
# 149     Cybersecurity  Network Security  Information Security Analyst
# 169     Cybersecurity  Network Security  Information Security Analyst
#
#       Python     SQL     Java
# 4    Average    Weak   Strong
# 15   Average    Weak   Strong
# 26   Average    Weak   Strong
# 37   Average    Weak   Strong
# 46      Weak  Strong  Average
# 55      Weak  Strong  Average
# 64      Weak  Strong  Average
# 73      Weak  Strong  Average
# 75      Weak  Strong  Average
# 77      Weak  Strong  Average
# 119  Average    Weak   Strong
# 129  Average    Weak   Strong
# 149  Average    Weak   Strong
# 169  Average    Weak   Strong

# %% [markdown]
# 8.What is the correlation between age and GPA among students?

# %%
data['Age'].corr(data['GPA'])
# Out:
# 0.20292469159722118

# %% [markdown]
# 9.How many students have "Weak" skills in both Python and Java?

# %%
data[(data['Java']=='Weak')&(data['Python']=='Weak')]## no one weak in both
# Out:
# Empty DataFrame
# Columns: [Student ID, Name, Gender, Age, GPA, Major, Interested Domain, Projects, Future Career, Python, SQL, Java]
# Index: []

# %% [markdown]
# 11.What are the top 3 most common projects worked on by students?

# %%
data['Projects'].value_counts().sort_values(ascending=False).head(3)
# Out:
# Projects
# Natural Language Processing    14
# Network Security               14
# E-commerce Website             13
# Name: count, dtype: int64

# %% [markdown]
# 12.What is the percentage of students aiming to become Software Engineers?

# %%
data[data['Future Career']=='Software Engineer']
# Out:
#      Student ID            Name  Gender  Age  GPA             Major  \
# 2             3    Robert Davis    Male   22  3.8  Computer Science
# 14           15     Susan Davis  Female   22  3.8  Computer Science
# 25           26     Susan Davis  Female   22  3.8  Computer Science
# 36           37     Susan Davis  Female   22  3.8  Computer Science
# 40           41    Peter Parker    Male   20  3.3  Computer Science
# 49           50      Fred Myers    Male   22  3.6  Computer Science
# 58           59         Sandman    Male   22  3.6  Computer Science
# 67           68         Morbius    Male   22  3.6  Computer Science
# 81           82      Agent Fitz    Male   35  3.9  Computer Science
# 117         118    Olivia Davis  Female   21  3.9  Computer Science
# 128         129     David Brown    Male   22  3.8  Computer Science
# 134         135  Isabella Brown  Female   20  3.6  Computer Science
# 147         148     Emma Wilson  Female   20  3.8  Computer Science
# 167         168     Emma Wilson  Female   20  3.8  Computer Science
#
#         Interested Domain                         Projects      Future Career  \
# 2    Software Development               E-commerce Website  Software Engineer
# 14   Software Engineering               E-commerce Website  Software Engineer
# 25   Software Engineering               E-commerce Website  Software Engineer
# 36   Software Engineering               E-commerce Website  Software Engineer
# 40   Software Development            Social Media Platform  Software Engineer
# 49   Software Development            Social Media Platform  Software Engineer
# 58   Software Development            Social Media Platform  Software Engineer
# 67   Software Development            Social Media Platform  Software Engineer
# 81   Software Development            Social Media Platform  Software Engineer
# 117  Software Development           Mobile App Development  Software Engineer
# 128  Software Engineering  Enterprise Software Development  Software Engineer
# 134  Software Development      Web Application Development  Software Engineer
# 147  Software Development           Mobile App Development  Software Engineer
# 167  Software Development           Mobile App Development  Software Engineer
#
#       Python     SQL     Java
# 2     Strong  Strong  Average
# 14    Strong  Strong  Average
# 25    Strong  Strong  Average
# 36    Strong  Strong  Average
# 40   Average    Weak   Strong
# 49   Average    Weak   Strong
# 58   Average    Weak   Strong
# 67   Average    Weak   Strong
# 81   Average    Weak   Strong
# 117   Strong  Strong  Average
# 128   Strong  Strong  Average
# 134   Strong    Weak   Strong
# 147   Strong  Strong  Average
# 167   Strong  Strong  Average

# %% [markdown]
# 13.What is the distribution of Python skills across different future careers?

# %%
h=data.groupby('Future Career')['Python'].value_counts()
sns.histplot(h)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %% [markdown]
# 14.How many students have "Strong" skills in all three programming languages (Python, SQL, Java)?

# %%
data[(data['Python']=='Strong')&(data['SQL']=='Strong')&(data['Java']=='Strong')]
# Out:
# Empty DataFrame
# Columns: [Student ID, Name, Gender, Age, GPA, Major, Interested Domain, Projects, Future Career, Python, SQL, Java]
# Index: []

# %% [markdown]
# 15.What is the most popular interested domain for students with a GPA below 3.0?

# %%
data.groupby(data['GPA']<3.0)['Interested Domain'].value_counts()
# Out:
# GPA    Interested Domain
# False  Artificial Intelligence           19
#        Web Development                   19
#        Cybersecurity                     18
#        Mobile App Development            17
#        Cloud Computing                   16
#        Database Management               16
#        Computer Graphics                 13
#        Data Science                      13
#        Machine Learning                  13
#        Software Development              11
#        Software Engineering               5
#        Biomedical Computing               2
#        Quantum Computing                  2
#        Bioinformatics                     2
#        Human-Computer Interaction         2
#        IoT (Internet of Things)           1
#        Network Security                   1
#        Natural Language Processing        1
#        Game Development                   1
#        Information Retrieval              1
#        Geographic Information Systems     1
#        Blockchain Technology              1
#        Digital Forensics                  1
#        Data Privacy                       1
#        Data Mining                        1
#        Computer Vision                    1
#        Distributed Systems                1
# Name: count, dtype: int64

# %% [markdown]
# 16.Who are the students with "Weak" SQL skills and want to pursue a career in Data Science?

# %%
data[(data['SQL']=='Weak')&(data['Interested Domain']=="Data Science")]
# Out:
#      Student ID          Name  Gender  Age  GPA             Major  \
# 142         143  Olivia Brown  Female   22  3.5  Computer Science
# 162         163  Olivia Brown  Female   22  3.5  Computer Science
#
#     Interested Domain     Projects Future Career   Python   SQL    Java
# 142      Data Science  Data Mining  Data Analyst  Average  Weak  Strong
# 162      Data Science  Data Mining  Data Analyst  Average  Weak  Strong

# %% [markdown]
# 17.What is the gender distribution of students with a GPA above 3.5?

# %%
data.groupby(data['GPA']<3.5)['Gender'].value_counts()
# Out:
# GPA    Gender
# False  Male      79
#        Female    71
# True   Male      23
#        Female     7
# Name: count, dtype: int64

# %% [markdown]
# 18.How many students aged 21 and above are interested in Web Development?

# %%
data[(data['Age']>=21)&(data['Interested Domain']=='Web Development')]
# Out:
#      Student ID              Name  Gender  Age  GPA             Major  \
# 3             4      Emily Wilson  Female   21  3.7  Computer Science
# 11           12       David Jones    Male   22  3.7  Computer Science
# 22           23       David Jones    Male   22  3.7  Computer Science
# 33           34       David Jones    Male   22  3.7  Computer Science
# 41           42  Mary Jane Watson  Female   21  3.7  Computer Science
# 50           51       Betty Brant  Female   21  3.7  Computer Science
# 80           81     Agent Simmons  Female   31  3.5  Computer Science
# 89           90     Michael Brown    Male   21  3.9  Computer Science
# 118         119     William Brown    Male   23  3.7  Computer Science
# 125         126      Olivia Davis  Female   22  3.7  Computer Science
# 135         136      Elijah Smith    Male   22  3.4  Computer Science
# 143         144        John Smith    Male   21  3.6  Computer Science
# 148         149      Oliver Brown    Male   23  3.7  Computer Science
# 155         156      Elijah Davis    Male   22  3.7  Computer Science
# 163         164        John Smith    Male   23  3.6  Computer Science
# 168         169      Oliver Brown    Male   23  3.7  Computer Science
# 175         176      Elijah Davis    Male   22  3.7  Computer Science
#
#     Interested Domain               Projects  Future Career  Python      SQL  \
# 3     Web Development     Full-Stack Web App  Web Developer    Weak   Strong
# 11    Web Development     Full-Stack Web App  Web Developer  Strong   Strong
# 22    Web Development     Full-Stack Web App  Web Developer  Strong   Strong
# 33    Web Development     Full-Stack Web App  Web Developer  Strong   Strong
# 41    Web Development     E-commerce Website  Web Developer    Weak   Strong
# 50    Web Development     E-commerce Website  Web Developer    Weak   Strong
# 80    Web Development     E-commerce Website  Web Developer    Weak   Strong
# 89    Web Development  Front-End Development  Web Developer  Strong  Average
# 118   Web Development     E-commerce Website  Web Developer    Weak   Strong
# 125   Web Development     Full-Stack Web App  Web Developer    Weak   Strong
# 135   Web Development     E-commerce Website  Web Developer    Weak   Strong
# 143   Web Development  Front-End Development  Web Developer    Weak   Strong
# 148   Web Development     E-commerce Website  Web Developer    Weak   Strong
# 155   Web Development     Full-Stack Web App  Web Developer    Weak   Strong
# 163   Web Development  Front-End Development  Web Developer    Weak   Strong
# 168   Web Development     E-commerce Website  Web Developer    Weak   Strong
# 175   Web Development     Full-Stack Web App  Web Developer    Weak   Strong
#
#         Java
# 3     Strong
# 11   Average
# 22   Average
# 33   Average
# 41    Strong
# 50    Strong
# 80    Strong
# 89      Weak
# 118   Strong
# 125   Strong
# 135   Strong
# 143  Average
# 148   Strong
# 155   Strong
# 163  Average
# 168   Strong
# 175   Strong

# %% [markdown]
# 19.Which future career is most common among female students?

# %%
data.groupby(data['Gender']=='Female')['Future Career'].max()
# Out:
# Gender
# False    Web Developer
# True     Web Developer
# Name: Future Career, dtype: object

# %%
data[(data['Gender']=='Female')&(data['Future Career'])].value_counts().idxmax()
# Out:
# (2,
#  'Alice Johnson',
#  'Female',
#  20,
#  3.2,
#  'Computer Science',
#  'Data Science',
#  'Data Analytics',
#  'Data Scientist',
#  'Average',
#  'Strong',
#  'Weak')

# %% [markdown]
# 20.What is the average GPA of students aiming to work in Machine Learning?

# %%
data.groupby(data['Future Career']=='Machine Learning Engineer')['GPA'].mean()
# Out:
# Future Career
# False    3.604790
# True     3.746154
# Name: GPA, dtype: float64
