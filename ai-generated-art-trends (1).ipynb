# %%
# Dataset link below.
import numpy as np
import pandas as pd

# %%
https://www.kaggle.com/datasets/waqi786/ai-generated-art-trends
# Out:
#   File "<ipython-input-1-b9f8e8d50e13>", line 1
#     https://www.kaggle.com/datasets/waqi786/ai-generated-art-trends
#           ^
# SyntaxError: invalid syntax

# %%
hi = pd.read_csv('/content/ai_generated_art_trends_2024.csv')
hi
# Out:
#      Artwork_ID       Artist_Name      Art_Style Creation_Date         Medium  \
# 0     ART-00001            DALL-E     Conceptual    2023-03-11        Collage
# 1     ART-00002      AbstractoBot       Futurism    2022-11-27      Oil Paint
# 2     ART-00003           Vincent       Futurism    2024-03-13       Charcoal
# 3     ART-00004        ArtBreeder  Impressionism    2022-09-12  Pencil Sketch
# 4     ART-00005            DALL-E     Surrealism    2022-12-05        Collage
# ...         ...               ...            ...           ...            ...
# 9995  ART-09996         RenoirBot     Conceptual    2024-01-22      Oil Paint
# 9996  ART-09997         RenoirBot        Pop Art    2023-04-05  Acrylic Paint
# 9997  ART-09998        ArtBreeder       Futurism    2023-01-27       3D Model
# 9998  ART-09999  GenerativeGenius         Cubism    2022-10-04  Acrylic Paint
# 9999  ART-10000  GenerativeGenius       Abstract    2022-12-07  Pencil Sketch
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 0       GANPaint           1604.25  South America       Urban   Instagram
# 1     MidJourney           4162.12  North America    Abstract    Dribbble
# 2       GANPaint           2989.38         Europe   Mythology      Reddit
# 3     ArtBreeder           2985.97         Europe  Still Life      Tumblr
# 4      DeepDream           2035.18           Asia  Conceptual  DeviantArt
# ...          ...               ...            ...         ...         ...
# 9995    GANPaint           3886.42        Oceania      Nature  DeviantArt
# 9996    GANPaint           4715.45        Oceania   Landscape   Instagram
# 9997   DeepDream            741.83         Europe  Conceptual     Behance
# 9998    GANPaint           2229.60         Africa    Portrait  DeviantArt
# 9999   DeepDream           3815.99           Asia       Urban     Twitter
#
#                                             Description  \
# 0     A mesmerizing piece of art that blends traditi...
# 1     A mesmerizing piece of art that blends traditi...
# 2     A mesmerizing piece of art that blends traditi...
# 3     A mesmerizing piece of art that blends traditi...
# 4     A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9995  A mesmerizing piece of art that blends traditi...
# 9996  A mesmerizing piece of art that blends traditi...
# 9997  A mesmerizing piece of art that blends traditi...
# 9998  A mesmerizing piece of art that blends traditi...
# 9999  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 0     https://example.com/artwork/00001.jpg
# 1     https://example.com/artwork/00002.jpg
# 2     https://example.com/artwork/00003.jpg
# 3     https://example.com/artwork/00004.jpg
# 4     https://example.com/artwork/00005.jpg
# ...                                     ...
# 9995  https://example.com/artwork/09996.jpg
# 9996  https://example.com/artwork/09997.jpg
# 9997  https://example.com/artwork/09998.jpg
# 9998  https://example.com/artwork/09999.jpg
# 9999  https://example.com/artwork/10000.jpg
#
# [10000 rows x 12 columns]

# %%
# Questions on dataset

# %% [markdown]
# ### 1.What are the different art styles present in the dataset?

# %%
# code here.
hi['Art_Style'].unique()
# Out:
# array(['Conceptual', 'Futurism', 'Impressionism', 'Surrealism',
#        'Abstract', 'Realism', 'Minimalism', 'Pop Art', 'Cubism',
#        'Expressionism'], dtype=object)

# %% [markdown]
# ### 2.How many artworks were created in the year 2023?

# %%
# code here.
hi['Creation_Date']=pd.to_datetime(hi['Creation_Date'])
b=hi[hi['Creation_Date']=='2023']
b
# Out:
#      Artwork_ID       Artist_Name      Art_Style Creation_Date         Medium  \
# 1830  ART-01831         DeepDream        Pop Art    2023-01-01      Oil Paint
# 3556  ART-03557        DaVinciNet        Realism    2023-01-01        Collage
# 3954  ART-03955        MidJourney  Expressionism    2023-01-01            Ink
# 4443  ART-04444        MidJourney     Minimalism    2023-01-01  Acrylic Paint
# 4596  ART-04597         PicassoAI         Cubism    2023-01-01       Charcoal
# 4929  ART-04930  GenerativeGenius       Abstract    2023-01-01        Digital
# 5080  ART-05081            DALL-E       Futurism    2023-01-01        Collage
# 5134  ART-05135           DeepArt     Minimalism    2023-01-01       3D Model
# 5676  ART-05677       AIArtist123     Conceptual    2023-01-01  Pencil Sketch
# 5815  ART-05816        DaVinciNet  Impressionism    2023-01-01    Mixed Media
# 6795  ART-06796           MonaBot     Conceptual    2023-01-01     Watercolor
# 7046  ART-07047           MonaBot         Cubism    2023-01-01        Digital
# 7530  ART-07531          GANPaint        Pop Art    2023-01-01  Acrylic Paint
# 7753  ART-07754           MonaBot  Expressionism    2023-01-01      Oil Paint
# 7761  ART-07762        ArtBreeder       Futurism    2023-01-01       3D Model
# 8614  ART-08615         PicassoAI         Cubism    2023-01-01        Collage
# 8918  ART-08919         PicassoAI  Expressionism    2023-01-01     Watercolor
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 1830  MidJourney            572.78  South America      Sci-Fi     Behance
# 3556    GANPaint           1004.88  North America      Nature      Tumblr
# 3954   DeepDream           1654.57           Asia       Urban     Twitter
# 4443      DALL-E           1513.96           Asia       Urban     Twitter
# 4596  MidJourney           2433.95        Oceania     Fantasy  ArtStation
# 4929  MidJourney           2013.82         Europe       Urban      Reddit
# 5080      DALL-E           2046.06  South America     Fantasy    Dribbble
# 5134   DeepDream            704.22  South America   Mythology     Behance
# 5676  MidJourney           1111.54           Asia     Fantasy   Instagram
# 5815    GANPaint           4769.42         Europe   Landscape      Flickr
# 6795  ArtBreeder           4104.70           Asia   Mythology      Reddit
# 7046  ArtBreeder           3410.20        Oceania   Landscape      Tumblr
# 7530    GANPaint            103.24        Oceania  Still Life    Dribbble
# 7753   DeepDream           1400.82           Asia     Fantasy   Pinterest
# 7761    GANPaint           3941.69        Oceania    Abstract      Flickr
# 8614   DeepDream           1023.89        Oceania   Mythology     Behance
# 8918   DeepDream           2847.54        Oceania      Nature   Pinterest
#
#                                             Description  \
# 1830  A mesmerizing piece of art that blends traditi...
# 3556  A mesmerizing piece of art that blends traditi...
# 3954  A mesmerizing piece of art that blends traditi...
# 4443  A mesmerizing piece of art that blends traditi...
# 4596  A mesmerizing piece of art that blends traditi...
# 4929  A mesmerizing piece of art that blends traditi...
# 5080  A mesmerizing piece of art that blends traditi...
# 5134  A mesmerizing piece of art that blends traditi...
# 5676  A mesmerizing piece of art that blends traditi...
# 5815  A mesmerizing piece of art that blends traditi...
# 6795  A mesmerizing piece of art that blends traditi...
# 7046  A mesmerizing piece of art that blends traditi...
# 7530  A mesmerizing piece of art that blends traditi...
# 7753  A mesmerizing piece of art that blends traditi...
# 7761  A mesmerizing piece of art that blends traditi...
# 8614  A mesmerizing piece of art that blends traditi...
# 8918  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 1830  https://example.com/artwork/01831.jpg
# 3556  https://example.com/artwork/03557.jpg
# 3954  https://example.com/artwork/03955.jpg
# 4443  https://example.com/artwork/04444.jpg
# 4596  https://example.com/artwork/04597.jpg
# 4929  https://example.com/artwork/04930.jpg
# 5080  https://example.com/artwork/05081.jpg
# 5134  https://example.com/artwork/05135.jpg
# 5676  https://example.com/artwork/05677.jpg
# 5815  https://example.com/artwork/05816.jpg
# 6795  https://example.com/artwork/06796.jpg
# 7046  https://example.com/artwork/07047.jpg
# 7530  https://example.com/artwork/07531.jpg
# 7753  https://example.com/artwork/07754.jpg
# 7761  https://example.com/artwork/07762.jpg
# 8614  https://example.com/artwork/08615.jpg
# 8918  https://example.com/artwork/08919.jpg

# %% [markdown]
# ### 3.Find all artworks that have a "Popularity_Score" greater than 4000.

# %%
# code here.
hi[hi['Popularity_Score']>400]
# Out:
#      Artwork_ID       Artist_Name      Art_Style Creation_Date         Medium  \
# 0     ART-00001            DALL-E     Conceptual    2023-03-11        Collage
# 1     ART-00002      AbstractoBot       Futurism    2022-11-27      Oil Paint
# 2     ART-00003           Vincent       Futurism    2024-03-13       Charcoal
# 3     ART-00004        ArtBreeder  Impressionism    2022-09-12  Pencil Sketch
# 4     ART-00005            DALL-E     Surrealism    2022-12-05        Collage
# ...         ...               ...            ...           ...            ...
# 9995  ART-09996         RenoirBot     Conceptual    2024-01-22      Oil Paint
# 9996  ART-09997         RenoirBot        Pop Art    2023-04-05  Acrylic Paint
# 9997  ART-09998        ArtBreeder       Futurism    2023-01-27       3D Model
# 9998  ART-09999  GenerativeGenius         Cubism    2022-10-04  Acrylic Paint
# 9999  ART-10000  GenerativeGenius       Abstract    2022-12-07  Pencil Sketch
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 0       GANPaint           1604.25  South America       Urban   Instagram
# 1     MidJourney           4162.12  North America    Abstract    Dribbble
# 2       GANPaint           2989.38         Europe   Mythology      Reddit
# 3     ArtBreeder           2985.97         Europe  Still Life      Tumblr
# 4      DeepDream           2035.18           Asia  Conceptual  DeviantArt
# ...          ...               ...            ...         ...         ...
# 9995    GANPaint           3886.42        Oceania      Nature  DeviantArt
# 9996    GANPaint           4715.45        Oceania   Landscape   Instagram
# 9997   DeepDream            741.83         Europe  Conceptual     Behance
# 9998    GANPaint           2229.60         Africa    Portrait  DeviantArt
# 9999   DeepDream           3815.99           Asia       Urban     Twitter
#
#                                             Description  \
# 0     A mesmerizing piece of art that blends traditi...
# 1     A mesmerizing piece of art that blends traditi...
# 2     A mesmerizing piece of art that blends traditi...
# 3     A mesmerizing piece of art that blends traditi...
# 4     A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9995  A mesmerizing piece of art that blends traditi...
# 9996  A mesmerizing piece of art that blends traditi...
# 9997  A mesmerizing piece of art that blends traditi...
# 9998  A mesmerizing piece of art that blends traditi...
# 9999  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 0     https://example.com/artwork/00001.jpg
# 1     https://example.com/artwork/00002.jpg
# 2     https://example.com/artwork/00003.jpg
# 3     https://example.com/artwork/00004.jpg
# 4     https://example.com/artwork/00005.jpg
# ...                                     ...
# 9995  https://example.com/artwork/09996.jpg
# 9996  https://example.com/artwork/09997.jpg
# 9997  https://example.com/artwork/09998.jpg
# 9998  https://example.com/artwork/09999.jpg
# 9999  https://example.com/artwork/10000.jpg
#
# [9282 rows x 12 columns]

# %% [markdown]
# ### 4.Calculate the total number of artworks for each "Region".

# %%
# code here
hi['Region'].value_counts()
# Out:
# Region
# South America    1728
# Europe           1700
# North America    1659
# Asia             1648
# Africa           1636
# Oceania          1629
# Name: count, dtype: int64

# %% [markdown]
# ### 5.What is the average "Popularity_Score" of artworks in the "Futurism" art style?

# %%
# code here.
hi.groupby('Art_Style')['Popularity_Score'].mean()
# Out:
# Art_Style
# Futurism    2508.190738
# Name: Popularity_Score, dtype: float64

# %% [markdown]
# ### 6.Sort the artworks by "Popularity_Score" and display the top 10 most popular artworks.

# %%
# code here.
hi['Popularity_Score'].sort_values().head(10)
# Out:
# 909     50.85
# 1833    51.17
# 6632    51.20
# 7673    51.74
# 7472    51.94
# 3840    52.24
# 7232    52.76
# 2145    53.11
# 6268    53.28
# 7131    54.93
# Name: Popularity_Score, dtype: float64

# %% [markdown]
# ### 7.Group the artworks by "Artist_Name" and calculate the average "Popularity_Score" for each artist.

# %%
# code here.
hi.groupby('Artist_Name')['Popularity_Score'].mean()
# Out:
# Artist_Name
# AIArtist123         2402.990198
# AbstractoBot        2438.509925
# ArtBreeder          2418.609719
# DALL-E              2490.125094
# DaVinciNet          2558.465712
# DeepArt             2591.649838
# DeepDream           2498.119969
# GANPaint            2549.093847
# GenerativeGenius    2566.583829
# MidJourney          2471.910375
# MonaBot             2487.533201
# NeoSurrealist       2480.058879
# PicassoAI           2510.702214
# RenoirBot           2598.548453
# Vincent             2563.740516
# Name: Popularity_Score, dtype: float64

# %% [markdown]
# ### 8.Group the data by "Art_Style" and count the number of artworks in each style.

# %%
hi['Art_Style'].value_counts()
# Out:
# Art_Style
# Cubism           1050
# Realism          1022
# Expressionism    1021
# Futurism         1016
# Pop Art          1008
# Impressionism     996
# Minimalism        995
# Surrealism        974
# Conceptual        969
# Abstract          949
# Name: count, dtype: int64

# %% [markdown]
# ### 9.How many artworks were created using each medium?

# %%
# code here.
hi['Medium'].value_counts()
# Out:
# Medium
# Pencil Sketch    1048
# Mixed Media      1041
# Acrylic Paint    1025
# Watercolor       1010
# Digital           999
# Collage           998
# Charcoal          983
# Oil Paint         979
# Ink               959
# 3D Model          958
# Name: count, dtype: int64

# %% [markdown]
# ### 10.Check for any missing values in the dataset.

# %%
# code here.
hi.isna().sum()
# Out:
# Artwork_ID          0
# Artist_Name         0
# Art_Style           0
# Creation_Date       0
# Medium              0
# Tools_Used          0
# Popularity_Score    0
# Region              0
# Art_Genre           0
# Platform            0
# Description         0
# Image_URL           0
# dtype: int64

# %% [markdown]
# ### 11.Calculate the standard deviation of the "Popularity_Score" for each "Art_Style".

# %%
# code here.
hi.describe(include='all')
# Out:
#        Artwork_ID Artist_Name Art_Style Creation_Date         Medium  \
# count       10000       10000     10000         10000          10000
# unique      10000          15        10           730             10
# top     ART-00001  MidJourney    Cubism    2023-05-02  Pencil Sketch
# freq            1         694      1050            28           1048
# mean          NaN         NaN       NaN           NaN            NaN
# std           NaN         NaN       NaN           NaN            NaN
# min           NaN         NaN       NaN           NaN            NaN
# 25%           NaN         NaN       NaN           NaN            NaN
# 50%           NaN         NaN       NaN           NaN            NaN
# 75%           NaN         NaN       NaN           NaN            NaN
# max           NaN         NaN       NaN           NaN            NaN
#
#        Tools_Used  Popularity_Score         Region Art_Genre  Platform  \
# count       10000      10000.000000          10000     10000     10000
# unique          5               NaN              6        10        10
# top     DeepDream               NaN  South America  Portrait  Dribbble
# freq         2032               NaN           1728      1049      1086
# mean          NaN       2508.190738            NaN       NaN       NaN
# std           NaN       1430.922879            NaN       NaN       NaN
# min           NaN         50.850000            NaN       NaN       NaN
# 25%           NaN       1267.712500            NaN       NaN       NaN
# 50%           NaN       2492.025000            NaN       NaN       NaN
# 75%           NaN       3763.245000            NaN       NaN       NaN
# max           NaN       4999.620000            NaN       NaN       NaN
#
#                                               Description  \
# count                                               10000
# unique                                                  1
# top     A mesmerizing piece of art that blends traditi...
# freq                                                10000
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                     Image_URL
# count                                   10000
# unique                                  10000
# top     https://example.com/artwork/00001.jpg
# freq                                        1
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                                       NaN

# %% [markdown]
# ### 12.Calculate the mean, median, and standard deviation of the "Popularity_Score" for artworks created using "GANPaint"

# %%
# code here.
hi[hi['Artist_Name']=='GANPaint'].describe()
# Out:
#        Popularity_Score
# count        668.000000
# mean        2549.093847
# std         1407.323690
# min           58.420000
# 25%         1411.217500
# 50%         2544.815000
# 75%         3827.385000
# max         4975.650000

# %% [markdown]
# ### 13.Count the number of artworks created by each artist

# %%
# code here.
hi['Artist_Name'].value_counts()
# Out:
# Artist_Name
# MidJourney          694
# DALL-E              691
# DaVinciNet          681
# NeoSurrealist       678
# DeepArt             678
# ArtBreeder          675
# GANPaint            668
# RenoirBot           666
# AbstractoBot        665
# PicassoAI           664
# Vincent             659
# AIArtist123         657
# MonaBot             656
# DeepDream           649
# GenerativeGenius    619
# Name: count, dtype: int64

# %% [markdown]
# ### 14.Filter the dataset to show only artworks created in "2024" using "Oil Paint".

# %%
# code here.
hi[(hi['Creation_Date']=='2024') & (hi['Medium']=='Oil Paint')]
# Out:
#      Artwork_ID       Artist_Name      Art_Style Creation_Date     Medium  \
# 3658  ART-03659         DeepDream        Realism    2024-01-01  Oil Paint
# 4311  ART-04312     NeoSurrealist       Abstract    2024-01-01  Oil Paint
# 5498  ART-05499  GenerativeGenius     Conceptual    2024-01-01  Oil Paint
# 6115  ART-06116           Vincent  Impressionism    2024-01-01  Oil Paint
#
#       Tools_Used  Popularity_Score         Region  Art_Genre    Platform  \
# 3658      DALL-E           3160.88        Oceania     Sci-Fi  ArtStation
# 4311    GANPaint             77.38  North America     Nature     Behance
# 5498      DALL-E           1991.66  North America     Sci-Fi     Twitter
# 6115  MidJourney           2179.48         Europe  Landscape  ArtStation
#
#                                             Description  \
# 3658  A mesmerizing piece of art that blends traditi...
# 4311  A mesmerizing piece of art that blends traditi...
# 5498  A mesmerizing piece of art that blends traditi...
# 6115  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 3658  https://example.com/artwork/03659.jpg
# 4311  https://example.com/artwork/04312.jpg
# 5498  https://example.com/artwork/05499.jpg
# 6115  https://example.com/artwork/06116.jpg

# %% [markdown]
# ### 15.Display all artworks that are either "Futurism" or "Impressionism" and have a "Popularity_Score" below 2000.

# %%
# code here.
hi[((hi['Art_Style'] == 'Futurism') | (hi['Art_Style'] == 'Impressionism')) & (hi['Popularity_Score'] < 2000)]
# Out:
#      Artwork_ID       Artist_Name      Art_Style Creation_Date         Medium  \
# 9     ART-00010        DaVinciNet  Impressionism    2023-09-13     Watercolor
# 29    ART-00030  GenerativeGenius       Futurism    2023-04-20  Acrylic Paint
# 36    ART-00037        MidJourney  Impressionism    2023-10-22        Collage
# 44    ART-00045         RenoirBot       Futurism    2023-10-07     Watercolor
# 49    ART-00050         RenoirBot       Futurism    2023-05-24        Collage
# ...         ...               ...            ...           ...            ...
# 9966  ART-09967            DALL-E  Impressionism    2023-03-15        Digital
# 9984  ART-09985         DeepDream  Impressionism    2023-04-17       3D Model
# 9986  ART-09987         PicassoAI       Futurism    2024-02-16  Pencil Sketch
# 9992  ART-09993         RenoirBot       Futurism    2024-04-04      Oil Paint
# 9997  ART-09998        ArtBreeder       Futurism    2023-01-27       3D Model
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 9         DALL-E           1188.63  North America    Abstract     Twitter
# 29    ArtBreeder            873.77           Asia  Conceptual   Pinterest
# 36      GANPaint           1833.19         Europe  Conceptual   Pinterest
# 44        DALL-E           1948.95        Oceania    Abstract      Reddit
# 49        DALL-E            281.43  North America    Portrait  ArtStation
# ...          ...               ...            ...         ...         ...
# 9966    GANPaint            880.38         Europe       Urban      Flickr
# 9984  ArtBreeder            892.33         Europe       Urban  DeviantArt
# 9986   DeepDream           1722.87           Asia  Still Life     Twitter
# 9992   DeepDream            385.71           Asia       Urban      Reddit
# 9997   DeepDream            741.83         Europe  Conceptual     Behance
#
#                                             Description  \
# 9     A mesmerizing piece of art that blends traditi...
# 29    A mesmerizing piece of art that blends traditi...
# 36    A mesmerizing piece of art that blends traditi...
# 44    A mesmerizing piece of art that blends traditi...
# 49    A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9966  A mesmerizing piece of art that blends traditi...
# 9984  A mesmerizing piece of art that blends traditi...
# 9986  A mesmerizing piece of art that blends traditi...
# 9992  A mesmerizing piece of art that blends traditi...
# 9997  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 9     https://example.com/artwork/00010.jpg
# 29    https://example.com/artwork/00030.jpg
# 36    https://example.com/artwork/00037.jpg
# 44    https://example.com/artwork/00045.jpg
# 49    https://example.com/artwork/00050.jpg
# ...                                     ...
# 9966  https://example.com/artwork/09967.jpg
# 9984  https://example.com/artwork/09985.jpg
# 9986  https://example.com/artwork/09987.jpg
# 9992  https://example.com/artwork/09993.jpg
# 9997  https://example.com/artwork/09998.jpg
#
# [796 rows x 12 columns]

# %% [markdown]
# ### 16.What is the most popular artwork (highest Popularity_Score)?

# %%
# code here.
hi['Popularity_Score'].max()
# Out:
# 4999.62

# %% [markdown]
# ### 17.What is the least popular artwork (lowest Popularity_Score)?

# %%
# code here.
hi['Popularity_Score'].min()
# Out:
# 50.85

# %% [markdown]
# ### 18.What is the most common art genre in Europe?

# %%
# code here.
hi[hi['Region']=='Europe'].value_counts().idxmax()
# Out:
# ('ART-00003',
#  'Vincent',
#  'Futurism',
#  '2024-03-13',
#  'Charcoal',
#  'GANPaint',
#  2989.38,
#  'Europe',
#  'Mythology',
#  'Reddit',
#  'A mesmerizing piece of art that blends traditional and modern techniques, showcasing the limitless possibilities of AI in creative expression.',
#  'https://example.com/artwork/00003.jpg')

# %% [markdown]
# ### 19.Export the dataset to a CSV file named "artwork_data.csv".

# %%
# code here.
hi.to_csv('artwork_data.csv')

# %% [markdown]
# ### 20.Group the data by Artist_Name and calculate the total number of artworks created by each artist.

# %%
# code here.
hi.groupby('Artist_Name').count()
# Out:
#                   Artwork_ID  Art_Style  Creation_Date  Medium  Tools_Used  \
# Artist_Name
# AIArtist123              657        657            657     657         657
# AbstractoBot             665        665            665     665         665
# ArtBreeder               675        675            675     675         675
# DALL-E                   691        691            691     691         691
# DaVinciNet               681        681            681     681         681
# DeepArt                  678        678            678     678         678
# DeepDream                649        649            649     649         649
# GANPaint                 668        668            668     668         668
# GenerativeGenius         619        619            619     619         619
# MidJourney               694        694            694     694         694
# MonaBot                  656        656            656     656         656
# NeoSurrealist            678        678            678     678         678
# PicassoAI                664        664            664     664         664
# RenoirBot                666        666            666     666         666
# Vincent                  659        659            659     659         659
#
#                   Popularity_Score  Region  Art_Genre  Platform  Description  \
# Artist_Name
# AIArtist123                    657     657        657       657          657
# AbstractoBot                   665     665        665       665          665
# ArtBreeder                     675     675        675       675          675
# DALL-E                         691     691        691       691          691
# DaVinciNet                     681     681        681       681          681
# DeepArt                        678     678        678       678          678
# DeepDream                      649     649        649       649          649
# GANPaint                       668     668        668       668          668
# GenerativeGenius               619     619        619       619          619
# MidJourney                     694     694        694       694          694
# MonaBot                        656     656        656       656          656
# NeoSurrealist                  678     678        678       678          678
# PicassoAI                      664     664        664       664          664
# RenoirBot                      666     666        666       666          666
# Vincent                        659     659        659       659          659
#
#                   Image_URL
# Artist_Name
# AIArtist123             657
# AbstractoBot            665
# ArtBreeder              675
# DALL-E                  691
# DaVinciNet              681
# DeepArt                 678
# DeepDream               649
# GANPaint                668
# GenerativeGenius        619
# MidJourney              694
# MonaBot                 656
# NeoSurrealist           678
# PicassoAI               664
# RenoirBot               666
# Vincent                 659
